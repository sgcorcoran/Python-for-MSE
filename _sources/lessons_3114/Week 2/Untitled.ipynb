# %%
import test

# %%
test.ln(3)
# Out:
# 1.0986122886681098

# %%
test.xyplt('Al7075_out.xlsx',1,0,'strain','stress, MPa')

# %%
from test import xyplt

# %%
xyplt('Al7075_out.xlsx',1,0,'strain','stress, MPa')

# %%
np.log(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b1692dd3c7bc> in <module>
# ----> 1 np.log(4)
#
# NameError: name 'np' is not defined
