# %% [markdown]
# # Lesson 7: Practical Research Project (Capstone)
# ## Integrating AI-Augmented Materials Science Skills
#
# **Duration**: 2 weeks (Weeks 11-12)
# **Weekly Workload**: 3 hours per week (6 hours total)
# **Learning Focus**: Apply all learned skills to a real materials science research question
#
# ---
#
# ## Project Learning Objectives
#
# By completing this project, you will:
# - **Apply AI tools** to a real materials science problem
# - **Integrate all learned skills** (Lessons 01-06) into a cohesive workflow
# - **Document AI usage** systematically for reproducibility
# - **Communicate findings** clearly and professionally
# - **Evaluate your own work** critically using validation strategies
#
# ---

# %% [markdown]
# ## 📋 **SUBMISSION REQUIREMENTS**
#
# **Turn in this notebook with all cells run showing output.**
#
# **Your notebook should contain:**
# - AI-assisted project plan (Week 11)
# - All data loading and validation (Week 11)
# - All exploratory analysis with output (Week 11)
# - All statistical analysis with output (Week 11)
# - All validation checkpoints completed (Week 11 & 12)
# - Complete analysis with final results (Week 12)
# - All workflow documentation (Week 12)
# - Technical report (Week 12)
#
# **Optional but Recommended**: Export your AI chat logs (ChatGPT/Claude conversations) and include in submission. This helps demonstrate your AI interaction process throughout the project.
#
# ---

# %% [markdown]
# ## Project Overview
#
# ### What You'll Do
#
# This project is your opportunity to demonstrate mastery of AI-augmented materials science by:
# - Applying all tools learned in Lessons 01-06
# - Working through a complete research workflow
# - Validating all AI outputs (critical from Lesson 05!)
# - Documenting your process for reproducibility
# - Communicating your findings clearly
#
# ### Project Timeline
#
# **Week 11: Planning & Analysis** (3 hours)
# - Project selection: 30 min
# - AI-assisted planning: 60 min
# - Data collection & initial analysis: 90 min
#
# **Week 12: Completion & Documentation** (3 hours)
# - Complete analysis & validation: 90 min
# - Documentation & report writing: 90 min
#
# **Total Time**: 6 hours over 2 weeks
#
# ### Deliverables (100 points total)
#
# 1. **Project Notebook** (40 points): Well-organized Jupyter notebook with all analysis
# 2. **Technical Report** (40 points): 3-4 page report of your findings
# 3. **Workflow Documentation** (20 points): AI usage log and workflow reflections
#
# **💡 For Python Beginners**: This project lets you use everything you've learned! Don't worry - you'll combine familiar pieces from previous lessons.
#
# ---

# %% [markdown]
# ## Week 11: Project Planning & Analysis (3 hours)
#
# ### Time Allocation
# - Phase 1: Project Selection (30 min)
# - Phase 2: AI-Assisted Planning (60 min)
# - Phase 3: Data Collection & Initial Analysis (90 min)
#
# ---

# %% [markdown]
# ### Phase 1: Project Selection (30 min)
#
# **Your Task**: Choose ONE project type that interests you.
#
# #### Option A: Composition-Property Relationships
#
# **Research Question**: How do alloy composition variables (e.g., Cu, Mg, Si content) relate to mechanical properties (e.g., yield strength, hardness)?
#
# **What You'll Do**:
# - Analyze composition data and mechanical properties
# - Identify correlations between composition and properties
# - Use statistical analysis to quantify relationships
# - Create visualizations showing relationships
#
# **Skills Used**: Data loading, statistical analysis, correlation analysis, visualization
#
# #### Option B: Processing Optimization
#
# **Research Question**: What are the optimal heat treatment conditions (temperature, time) for achieving target mechanical properties?
#
# **What You'll Do**:
# - Analyze experimental data with different processing conditions
# - Compare treatment groups statistically
# - Identify optimal conditions based on analysis
# - Create visualizations comparing treatments
#
# **Skills Used**: Statistical comparison, group analysis, visualization, optimization
#
# #### Option C: Material Classification
#
# **Research Question**: Can materials be classified based on their properties? What properties best distinguish material types?
#
# **What You'll Do**:
# - Analyze property data for different material types
# - Use statistical tests to compare property distributions
# - Identify which properties best distinguish materials
# - Create visualizations showing classification
#
# **Skills Used**: Statistical comparison, property analysis, visualization, classification
#
# **Your Choice**:
#
# **Project Selected**: [Write Option A, B, or C]
#
# **Why This Project**:
#
#
#
# ---

# %% [markdown]
# ### Phase 2: AI-Assisted Project Planning (60 min)
#
# **Your Task**: Use AI to help plan your project systematically.
#
# #### Step 1: Create Planning Prompt (15 min)
#
# **Instructions**: Create a prompt asking AI to help plan your project.
#
# **Prompt Template**:
#
# ```
# I'm working on a materials science research project for MSE 3114.
#
# Project Type: [Your selected option A, B, or C]
# Research Question: [Your specific question]
#
# Please help me plan this project by:
# 1. Identifying what data I'll need
# 2. Suggesting appropriate analyses (statistical tests)
# 3. Recommending visualizations
# 4. Creating a step-by-step workflow
# 5. Estimating time for each step
#
# Constraints:
# - Must use skills from Lessons 01-06
# - Must validate all AI outputs (from Lesson 05)
# - Must document AI usage throughout
# - Final deliverable: 3-4 page report + notebook
#
# Please provide a structured project plan.
# ```
#
# **Your Task**: Customize this prompt for your selected project and paste it into ChatGPT or Claude.
#
# ---

# %% [markdown]
# ### AI Project Plan Response
#
# **Paste the AI's project plan here:**
#
# ```
#
#
#
# ```
#
#
# ---

# %% [markdown]
# ### Step 2: Validate and Refine Plan (15 min)
#
# **Your Task**: Critically evaluate the AI's plan (remember Lesson 05!).
#
# **Validation Checklist:**
#
# - [ ] Does the plan address your research question?
# - [ ] Are the suggested analyses appropriate for your data type?
# - [ ] Is the workflow logical and achievable?
# - [ ] Are time estimates realistic?
# - [ ] Does the plan include validation steps?
# - [ ] Does the plan include documentation requirements?
#
# **Your Validated Plan** (write it out below):
#
# **Project Workflow:**
#
# 1. **Step 1**: [Your step]
#    - Tool/Technique:
#    - Time estimate:
#
# 2. **Step 2**:
#    - Tool/Technique:
#    - Time estimate:
#
# 3. **Step 3**:
#    - Tool/Technique:
#    - Time estimate:
#
# 4. **Step 4**:
#    - Tool/Technique:
#    - Time estimate:
#
# 5. **Step 5**:
#    - Tool/Technique:
#    - Time estimate:
#
# **Note**: Your plan should have 4-6 steps total.
#
# ---

# %% [markdown]
# ### Phase 3: Data Collection & Initial Analysis (90 min)
#
# **Your Task**: Get your data and start the analysis workflow.
#
# #### Step 1: Data Collection (15 min)
#
# **Data Options:**
#
# **Option 1**: Use data from previous lessons
# - Heat treatment data from Lesson 05
# - Alloy data from Lesson 02
# - Any other datasets you've worked with
#
# **Option 2**: Use provided datasets (if available)
# - Check Canvas for project datasets
# - Download and save in your project folder
#
# **Option 3**: Use publicly available materials science datasets
# - Matbench (materials property database)
# - NIST Materials Data Repository
# - Other materials science databases
#
# **Your Data Source**:
#
# **Data Description**:
# - What does the data contain?
# - How many samples?
# - What variables/columns?
#
# ---

# %%
# === Phase 3: Data Collection & Initial Analysis ===

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

print("="*70)
print("PHASE 3: DATA COLLECTION & INITIAL ANALYSIS")
print("="*70)

# === Step 2: Load and Validate Data (15 min) ===
print("\nStep 2: Loading data...")

# TODO: Load your data
# data = pd.read_csv('your_data_file.csv')
# OR
# data = pd.read_json('your_data_file.json')

# TODO: Validate data loaded correctly
# print(f"Data shape: {data.shape}")
# print(f"Columns: {list(data.columns)}")
# print(data.head())
# print(data.info())

# TODO: Check for missing values
# print(f"Missing values: {data.isnull().sum().sum()}")

# TODO: Check data types
# print(data.dtypes)

# HINT: Use what you learned in Lesson 01!

print("\nData validation complete!")

# ================================================================
# VALIDATION CHECKPOINT 1: Data Loading (CRITICAL!)
# ================================================================
# WHY: You must validate data loaded correctly before analysis!
# If data didn't load, all subsequent analysis will fail

# TODO: Complete this validation checklist:
# - [ ] Data shape looks reasonable (not 0 rows or columns)
# - [ ] Column names match what you expected
# - [ ] No obvious errors in first few rows
# - [ ] Missing values are acceptable (not too many)
# - [ ] Data types are correct (numbers are numeric, not strings)

# Validation questions:
# 1. Does data.shape make sense? (e.g., if expecting 40 samples, check shape[0] == 40)
# 2. Are the column names what you expected?
# 3. Do the first few rows look reasonable?
# 4. Are there too many missing values? (e.g., >10% might be problematic)

# TODO: Write a brief validation summary:
# print("\nValidation Summary:")
# print("Data loaded successfully: YES/NO")
# print("Shape: [your observations]")
# print("Any issues found: [describe any problems]")

# %%
# === Step 3: Exploratory Data Analysis (20 min) ===

print("="*70)
print("EXPLORATORY DATA ANALYSIS")
print("="*70)

# WHY: Exploratory analysis helps you understand your data before statistical testing
# This prevents choosing inappropriate tests or missing important patterns

# TODO: Calculate descriptive statistics
# HINT: Use data.describe() for numerical columns
# For groups: data.groupby('your_group_column')['your_value_column'].describe()

# TODO: Create initial visualizations based on your project type:
# HINT: Use what you learned in Lesson 04!

# OPTION A (Composition-Property Relationships):
# WHY: You need to see relationships between composition and properties
# - Use scatter plots: plt.scatter(data['Cu_content'], data['Yield_Strength'])
# - Multiple scatter plots for different composition variables
# - Check for linear or nonlinear relationships
# Example:
# plt.figure(figsize=(10, 6))
# plt.scatter(data['composition_column'], data['property_column'])
# plt.xlabel('Composition (wt%)')
# plt.ylabel('Property (MPa or HV)')
# plt.title('Relationship: Composition vs Property')
# plt.tight_layout()
# plt.show()

# OPTION B (Processing Optimization):
# WHY: You need to compare different treatment groups
# - Use boxplots: sns.boxplot(data=data, x='Treatment', y='Property')
# - Compare distributions of properties for different treatments
# Example:
# plt.figure(figsize=(10, 6))
# sns.boxplot(data=data, x='Treatment_Column', y='Property_Column')
# plt.title('Property by Treatment')
# plt.xlabel('Treatment')
# plt.ylabel('Property (with units!)')
# plt.tight_layout()
# plt.show()

# OPTION C (Material Classification):
# WHY: You need to see if material types have different properties
# - Use boxplots comparing properties across material types
# - Use histograms to see property distributions for each type
# Example:
# plt.figure(figsize=(10, 6))
# sns.boxplot(data=data, x='Material_Type', y='Property')
# plt.title('Property by Material Type')
# plt.xlabel('Material Type')
# plt.ylabel('Property (with units!)')
# plt.tight_layout()
# plt.show()

print("\nExploratory analysis complete!")

# Make sure your exploratory analysis output is visible in the notebook

# %%
# === Step 4: Statistical Analysis (25 min) ===

print("="*70)
print("STATISTICAL ANALYSIS")
print("="*70)

# TODO: Choose appropriate statistical test based on your project type
# HINT: Use what you learned in Lessons 04 and 05!

# For Option A (Composition-Property Relationships):
# - Use correlation analysis: stats.pearsonr() or stats.spearmanr()
# - Or linear regression

# For Option B (Processing Optimization):
# - Compare groups: stats.ttest_ind() or stats.mannwhitneyu()
# - Check assumptions first (normality, equal variances)

# For Option C (Material Classification):
# - Compare property distributions between material types
# - Use appropriate test for multiple groups

# TODO: Separate data by groups (if needed)
# group_a = data[data['group_column'] == 'value_a']['value_column']
# group_b = data[data['group_column'] == 'value_b']['value_column']

# TODO: Check assumptions (normality, equal variances)
# For normality: stats.shapiro() or stats.normaltest()
# result_a = stats.shapiro(group_a)
# print(f"Group A normality: p = {result_a.pvalue:.4f}")

# TODO: Run appropriate statistical test
# For two independent groups:
# result = stats.ttest_ind(group_a, group_b)
# print(f"T-test: p-value = {result.pvalue:.4f}")
# if result.pvalue < 0.05:
#     print("Significant difference detected!")

# TODO: Validate your test choice (remember Lesson 05!)
# - Did you check assumptions?
# - Is the test appropriate for your question?
# - Are you interpreting correctly?

print("\nStatistical analysis complete!")

# ================================================================
# VALIDATION CHECKPOINT 2: Statistical Analysis (CRITICAL!)
# ================================================================
# WHY: Statistical tests must be appropriate for your question and data!
# Wrong test = wrong conclusions = wrong science!

# TODO: Complete this validation checklist:
# - [ ] Test is appropriate for your research question
# - [ ] Assumptions were checked before running test
# - [ ] Assumptions are met (or non-parametric test used)
# - [ ] Results make sense (p-values reasonable, effect sizes plausible)
# - [ ] Interpretation is correct (not confusing correlation with causation)

# Validation questions:
# 1. Does your test answer your research question?
#    - Option A: Test for correlation/relationship (Pearson/Spearman)
#    - Option B: Test for differences between groups (t-test/Mann-Whitney)
#    - Option C: Test for differences between material types (ANOVA/Kruskal-Wallis)
# 2. Are assumptions met?
#    - If using parametric test (t-test, ANOVA): Is data normal? Equal variances?
#    - If assumptions violated: Did you use non-parametric test?
# 3. Do results make sense?
#    - Are p-values reasonable? (not exactly 0.0000, not > 0.99)
#    - Are effect sizes plausible for materials science?
#    - Would a materials scientist agree with your interpretation?

# TODO: Write a brief validation summary:
# print("\nStatistical Validation Summary:")
# print("Test selected: [your test]")
# print("Assumptions checked: YES/NO")
# print("Assumptions met: YES/NO (if no, did you use non-parametric?)")
# print("Results reasonable: YES/NO")
# print("Any concerns: [describe any issues]")

# Make sure your statistical analysis output is visible in the notebook

# %% [markdown]
# ### ✅ Week 11 Checkpoint - End of Week 11
#
# **💡 Why This Matters**: This checkpoint helps you track progress and ensure you're ready for Week 12!
#
# **At the end of Week 11, you should have:**
#
# - [ ] Selected your project type (Option A, B, or C)
# - [ ] Created AI-assisted project plan
# - [ ] Validated and refined your plan (remember Lesson 05!)
# - [ ] Collected your data
# - [ ] Loaded and validated data (Validation Checkpoint 1 completed)
# - [ ] Completed exploratory data analysis
# - [ ] Completed initial statistical analysis
# - [ ] Validated statistical analysis (Validation Checkpoint 2 completed)
# - [ ] Validated all AI recommendations (Lesson 05 skills applied!)
#
# **Progress Check**:
# - ✅ If all checked: You're ready for Week 12! Great work!
# - ⚠️ If 6-7 checked: You're mostly on track - review missing items
# - 🔴 If <6 checked: Don't worry! Prioritize data loading and initial analysis. You can refine in Week 12.
#
# **💡 Why This Matters**: It's better to do fewer steps well than rush through everything. Quality over quantity!
#
# ---

# %% [markdown]
# ## Week 12: Completion & Documentation (3 hours)
#
# ### 🎯 Week 12 Starting Point
#
# **Welcome to Week 12!** You're in the final phase of your capstone project.
#
# **💡 Why This Matters**: Week 12 is about completing your analysis, validating everything, and communicating your findings clearly.
#
# **What You Should Have from Week 11:**
# - ✅ Project selected and planned
# - ✅ Data loaded and validated
# - ✅ Initial analysis completed
# - ✅ Validation checkpoints completed
#
# **If you're behind from Week 11**: That's okay! Focus on:
# 1. Complete data loading and validation (most important!)
# 2. Complete at least one statistical analysis
# 3. Create at least one visualization
#
# **💡 Why This Matters**: A complete analysis of one question is better than incomplete analysis of many questions!
#
# ### Time Allocation
# - Phase 4: Complete Analysis & Validation (90 min)
# - Phase 5: Documentation & Report Writing (90 min)
#
# ---

# %%
# === Phase 4: Complete Analysis & Validation (90 min) ===

print("="*70)
print("PHASE 4: COMPLETE ANALYSIS & VALIDATION")
print("="*70)

# === Step 1: Complete Any Remaining Analysis ===
# TODO: Finish any incomplete analyses from Week 11
# TODO: Add any additional analyses your project needs
# TODO: Create final visualizations

# === Step 2: Validation (CRITICAL!) ===
print("\n" + "="*70)
print("VALIDATION CHECKLIST (Remember Lesson 05!)")
print("="*70)

# TODO: Validate all your work
# - [ ] Code runs without errors
# - [ ] Statistical tests are appropriate
# - [ ] Assumptions checked and met
# - [ ] Results make sense (reasonable values)
# - [ ] Visualizations are accurate
# - [ ] AI outputs validated

print("\nValidation items to check:")
print("1. All code runs successfully")
print("2. Statistical tests are appropriate for your data")
print("3. Assumptions are checked and met")
print("4. Results are reasonable (check units, magnitudes)")
print("5. Visualizations accurately represent your data")
print("6. All AI recommendations were validated")

# TODO: Create final, publication-ready visualizations
# WHY: Good visualizations communicate your findings clearly
# HINT: Use matplotlib or seaborn with proper formatting
# - Clear titles and axis labels WITH UNITS
# - Appropriate figure size (usually 8x6 or 10x6 inches)
# - Professional appearance (not too colorful, clear fonts)

# OPTION A (Composition-Property): Scatter plot with trend line
# OPTION B (Processing Optimization): Boxplot comparing treatments
# OPTION C (Material Classification): Boxplot comparing material types

print("\n" + "="*70)
print("ANALYSIS COMPLETE!")
print("="*70)

# ================================================================
# VALIDATION CHECKPOINT 3: Final Analysis Review (CRITICAL!)
# ================================================================
# WHY: Final validation catches errors before you write your report!
# It's easier to fix now than after writing everything up

# TODO: Complete this final validation checklist:
# - [ ] All code runs without errors
# - [ ] Statistical tests are appropriate for your question
# - [ ] Results are reasonable (check units, magnitudes)
#   - Example: Yield strength of Al alloys should be 200-500 MPa
#   - Example: Hardness of Al T6 should be 120-170 HV
# - [ ] Visualizations accurately represent your data
# - [ ] All labels include units (critical for materials science!)
# - [ ] All AI outputs were validated (remember Lesson 05!)
# - [ ] Results answer your research question

# TODO: Write final validation summary:
# print("\nFinal Validation Summary:")
# print("All analyses completed: YES/NO")
# print("All validations passed: YES/NO")
# print("Ready for report writing: YES/NO")
# print("Any final concerns: [describe any issues]")

# Make sure your final analysis output is visible in the notebook

# %% [markdown]
# ### Phase 5: Documentation & Report Writing (90 min)
#
# **Your Task**: Document your work and write a brief technical report.
#
# #### Step 1: Document AI Usage (20 min)
#
# **Instructions**: Create a complete log of all AI tool usage throughout your project.
#
# **AI Usage Log Template:**
#
# | Stage | AI Tool | What You Asked | AI Response | How You Validated |
# |-------|---------|----------------|-------------|-------------------|
# | Planning | ChatGPT/Claude | [Your prompt] | [Summary of response] | [Validation method] |
# | Data Analysis | ChatGPT/Claude | [Your prompt] | [Summary] | [Validation] |
# | Statistical Test | ChatGPT/Claude | [Your prompt] | [Summary] | [Validation] |
# | Visualization | ChatGPT/Copilot | [Your prompt] | [Summary] | [Validation] |
# | Report Writing | ChatGPT/Claude | [Your prompt] | [Summary] | [Validation] |
#
# **Fill out your AI usage log:**
#
# ---

# %% [markdown]
# #### Step 2: Workflow Documentation (10 min)
#
# **Your Task**: Document your complete workflow.
#
# **Workflow Documentation Template:**
#
# **Complete Workflow Steps:**
#
# 1. **Planning**: Used AI to plan project → Validated plan → Refined workflow
# 2. **Data Loading**: Loaded data from [source] → Validated data quality → Checked for errors
# 3. **Exploratory Analysis**: Calculated descriptive statistics → Created initial visualizations → Identified patterns
# 4. **Statistical Analysis**: Selected appropriate test → Checked assumptions → Ran test → Validated results
# 5. **Final Analysis**: Completed remaining analyses → Validated all results → Created final visualizations
# 6. **Documentation**: Documented AI usage → Created workflow log → Wrote technical report
#
# **Time Efficiency Reflection** (≤150 words):
#
# How did using integrated workflows (from Lesson 06) help you in this project? What took longest? What would you do differently next time?
#
# **Your Answer**:
#
#
#
#
#
# **💡 Important**: Make sure your workflow documentation is complete and visible in the notebook!
#
# ---

# %% [markdown]
# #### Step 3: Write Technical Report (60 min)
#
# **Your Task**: Write a brief 3-4 page technical report.
#
# **Report Structure:**
#
# **1. Introduction (1/2 page)**
# - What research question are you addressing?
# - Why is this question important?
# - What approach did you take?
#
# **2. Methodology (1 page)**
# - What data did you use? (source, description)
# - What analyses did you perform? (statistical tests, visualizations)
# - How did you use AI tools? (document AI usage clearly)
# - How did you validate your results? (important!)
#
# **3. Results (1-1.5 pages)**
# - Present your key findings
# - Include tables or figures (from your notebook)
# - Report statistical test results
# - Present descriptive statistics
#
# **4. Discussion (1/2 page)**
# - What do your results mean?
# - What are the implications?
# - What are the limitations?
# - What would you do differently?
#
# **5. Conclusion (1/2 page)**
# - Summary of main findings
# - Key takeaways
# - Future directions
#
# **💡 Report Writing Tip**: You can use AI to help draft sections, but YOU must:
# 1. Validate all AI-generated content for accuracy
# 2. Edit and refine the writing
# 3. Ensure technical accuracy
# 4. Add your own insights and interpretations
#
# **AI-Assisted Report Writing Prompt Template:**
#
# ```
# I need help writing the [Introduction/Methodology/Results/Discussion] section of my materials science research report.
#
# My research question is: [Your question]
# My key findings are: [Your findings]
# My methodology was: [Your methods]
#
# Please write a draft for this section (approximately [X] pages/words).
# Use clear, professional scientific writing.
# Include specific details from my analysis.
#
# After you provide a draft, I will validate and edit it for accuracy.
# ```
#
# **Remember**: Always validate AI-generated writing! Check for:
# - Technical accuracy
# - Correct use of terms
# - Appropriate interpretation of results
# - Clear communication
#
# **Write your report below** (or in a separate document - submit as PDF):
#
# ---

# %% [markdown]
# ### 📝 Report Writing Template (Guided Structure)
#
# **💡 Why This Matters**: Following a structured template helps you organize your thoughts and ensure you include all necessary sections!
#
# **You can write your report here, or write it in a separate document (Word/Google Docs) and submit as PDF.**
#
# **Instructions**: Fill out each section below. You can use AI to help draft, but YOU must:
# 1. Validate all AI-generated content for accuracy
# 2. Edit and refine the writing
# 3. Add your own insights and interpretations
# 4. Ensure technical accuracy
#
# ---

# %% [markdown]
# ## 1. Introduction (1/2 page)
#
# **💡 Why This Matters**: The introduction sets the context for your work and helps readers understand why your question matters.
#
# **What to Include:**
# - What research question are you addressing?
# - Why is this question important for materials science?
# - What approach did you take?
#
# **Template Questions to Answer:**
# - "I investigated [your research question]"
# - "This question is important because [why it matters in MSE]"
# - "I approached this by [brief overview of your methodology]"
#
# **Your Introduction** (write below):
#
#
#
#
#
# ---

# %% [markdown]
# ## 2. Methodology (1 page)
#
# **💡 Why This Matters**: Methodology tells readers how you conducted your analysis. This must be clear for reproducibility!
#
# **What to Include:**
# - **Data Source**: What data did you use? (source, description, number of samples)
# - **Data Processing**: How did you prepare your data? (cleaning, validation steps)
# - **Analysis Methods**: What analyses did you perform? (statistical tests, visualizations)
# - **AI Usage**: How did you use AI tools? (document clearly - important!)
# - **Validation**: How did you validate your results? (assumption checks, validation steps)
#
# **Template Structure:**
# 1. **Data**: "I analyzed [dataset name] containing [description]"
# 2. **Processing**: "I validated data by [steps taken]"
# 3. **Analysis**: "I performed [statistical test] to answer [question]"
# 4. **AI Usage**: "I used [AI tool] for [specific task], and validated outputs by [method]"
# 5. **Validation**: "I validated results by [checks performed]"
#
# **Your Methodology** (write below):
#
#
#
#
#
# ---

# %% [markdown]
# ## 3. Results (1-1.5 pages)
#
# **💡 Why This Matters**: Results present your findings objectively. Include numbers, tables, and figures!
#
# **What to Include:**
# - **Descriptive Statistics**: Means, standard deviations, sample sizes
# - **Statistical Test Results**: Test name, p-values, effect sizes
# - **Figures**: Include 1-2 key visualizations (can reference from notebook)
# - **Tables**: If helpful for presenting data
#
# **Template Structure:**
# 1. **Descriptive Statistics**: "Mean [property] for [group A] was [value] ± [std], and for [group B] was [value] ± [std]"
# 2. **Statistical Test**: "I performed [test name] and found p = [value]"
# 3. **Interpretation**: "This indicates [what the p-value means]"
# 4. **Visualizations**: "Figure 1 shows [description of figure]"
#
# **💡 For Python Beginners**: Don't worry if you can't create fancy tables. Simple text descriptions are fine!
#
# **Your Results** (write below):
#
#
#
#
#
# ---

# %% [markdown]
# ## 4. Discussion (1/2 page)
#
# **💡 Why This Matters**: Discussion interprets your results and explains what they mean for materials science!
#
# **What to Include:**
# - **Interpretation**: What do your results mean?
# - **Implications**: What are the practical implications?
# - **Limitations**: What are the limitations of your analysis?
# - **Future Work**: What would you do differently or investigate next?
#
# **Template Questions to Answer:**
# - "My results show that [interpretation]"
# - "This is important because [implications for MSE]"
# - "Limitations include [what might affect results]"
# - "Future work could [what to do next]"
#
# **Your Discussion** (write below):
#
#
#
#
#
# ---

# %% [markdown]
# ## 5. Conclusion (1/2 page)
#
# **💡 Why This Matters**: Conclusion summarizes your main findings and key takeaways.
#
# **What to Include:**
# - **Summary**: Brief summary of main findings
# - **Key Takeaways**: What did you learn?
# - **Future Directions**: What would you investigate next?
#
# **Template Structure:**
# 1. **Summary**: "I investigated [question] and found [main finding]"
# 2. **Takeaways**: "Key takeaways are [1-2 main points]"
# 3. **Future**: "Future work could [suggestions]"
#
# **Your Conclusion** (write below):
#
#
#
#
#
#
# ---

# %% [markdown]
# ## Final Project Deliverables
#
# **Due**: End of Week 12
# **Points**: 100 points total
#
# ### 1. Project Notebook (40 points)
#
# **Requirements:**
# - Well-organized Jupyter notebook (`.ipynb` file)
# - All cells run successfully with output visible
# - Clear section headers and organization
# - All analysis code included
# - AI usage clearly documented
# - Validation steps included
#
# ### 2. Technical Report (40 points)
#
# **Requirements:**
# - 3-4 pages (not longer!)
# - Professional scientific writing
# - All sections included (Introduction, Methodology, Results, Discussion, Conclusion)
# - AI usage documented in methodology section
# - Validation approach explained
# - Submitted as PDF
#
# ### 3. Workflow Documentation (20 points)
#
# **Requirements:**
# - Complete AI usage log
# - Workflow documentation
# - Time efficiency reflections
# - Can be in notebook or separate document
#
# ### 4. AI Chat Logs (Optional but Recommended)
#
# - AI chat logs exported
# - Clear captions
#
# **Submission Format:**
# - Notebook: `.ipynb` file
# - Report: PDF file
# - Documentation: PDF or in notebook
# - AI logs: PDF or text file (optional)
#
# ---

# %% [markdown]
# ## Grading Rubric (100 points)
#
# ### Project Notebook (40 points)
#
# | Criterion | Excellent (full points) | Good (80%) | Satisfactory (60%) | Needs Improvement (<60%) | Points |
# |-----------|------------------------|-----------|-------------------|--------------------------|--------|
# | **Organization** | Well-organized, clear sections, professional appearance | Good organization, minor issues | Basic organization | Poor organization | 10 |
# | **Code Quality** | All code runs successfully, clear comments, appropriate analyses | Most code works, some comments | Code mostly works | Code has errors or missing | 15 |
# | **Analysis Completeness** | All planned analyses completed, appropriate tests used | Most analyses completed | Some analyses completed | Incomplete analyses | 10 |
# | **Documentation** | AI usage clearly documented throughout, validation steps shown | Good documentation | Partial documentation | Minimal documentation | 5 |
#
# ### Technical Report (40 points)
#
# | Criterion | Excellent (full points) | Good (80%) | Satisfactory (60%) | Needs Improvement (<60%) | Points |
# |-----------|------------------------|-----------|-------------------|--------------------------|--------|
# | **Content** | All sections included, comprehensive, accurate | All sections, minor gaps | Most sections included | Missing sections or inaccurate | 15 |
# | **Writing Quality** | Clear, professional, well-written | Good writing, minor issues | Adequate writing | Poor writing quality | 10 |
# | **Technical Accuracy** | All technical content accurate, results correctly interpreted | Mostly accurate | Some inaccuracies | Significant inaccuracies | 10 |
# | **AI Usage Documentation** | AI usage clearly documented in methodology | AI usage mentioned | Partial documentation | No AI documentation | 5 |
#
# ### Workflow Documentation (20 points)
#
# | Criterion | Excellent (full points) | Good (80%) | Satisfactory (60%) | Needs Improvement (<60%) | Points |
# |-----------|------------------------|-----------|-------------------|--------------------------|--------|
# | **AI Usage Log** | Complete log with validation methods for all AI interactions | Good log, minor gaps | Partial log | Incomplete log | 10 |
# | **Workflow Documentation** | Detailed workflow steps, time reflections, efficiency insights | Good documentation | Basic documentation | Minimal documentation | 10 |
#
# ---

# %% [markdown]
# ## Congratulations! 🎉
#
# You've completed the MSE 3114 Capstone Project!
#
# ### What You've Accomplished
#
# You've successfully demonstrated mastery of AI-augmented materials science by:
#
# ✅ **Applying AI tools** strategically to real research questions
# ✅ **Integrating multiple tools** into efficient workflows
# ✅ **Validating all AI outputs** using critical evaluation skills
# ✅ **Documenting your work** systematically for reproducibility
# ✅ **Communicating findings** clearly and professionally
# ✅ **Evaluating your own work** critically
#
# ### Skills You've Mastered
#
# Throughout Lessons 01-07, you've learned:
# - **AI Tool Mastery**: ChatGPT, Claude, GitHub Copilot
# - **Prompt Engineering**: Effective AI communication
# - **Data Processing**: Pandas, Polars for efficient data handling
# - **Visualization**: Matplotlib, Seaborn, Plotly, Streamlit
# - **Statistical Analysis**: Hypothesis testing, validation
# - **AI Validation**: Critical evaluation of AI outputs
# - **Workflow Integration**: Efficient research workflows
# - **Documentation**: Reproducible research practices
#
# ### Moving Forward
#
# These skills will serve you well in:
# - **Research Projects**: Undergraduate research, thesis work
# - **Industry**: Internships, co-ops, full-time positions
# - **Graduate School**: Research assistantships, dissertation work
# - **Personal Projects**: Your own materials science interests
#
# **Remember**: AI is a powerful assistant, but **you** are the scientist. Always validate, always think critically, and always document your work!
#
# **Thank you for taking MSE 3114!**
#
# ---
