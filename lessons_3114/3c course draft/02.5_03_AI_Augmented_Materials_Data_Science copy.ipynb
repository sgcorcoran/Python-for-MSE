# %% [markdown]
# # Lesson 2.5-3: AI-Augmented Materials Data Science
# ## Modernizing Data Processing with Intelligent Tools
#
# **Duration**: 2 weeks (Weeks 4-5)
# **Weekly Workload**: 4-5 hours
# **Learning Focus**: AI-assisted data processing, modern tool selection, and interactive dashboard creation
#
# **Course Alignment**: This modernized lesson combines the best elements of lessons 02.5 and 03, integrating modern pedagogical approaches with AI tool mastery for materials science applications.
#
# ---
#
# ## Learning Objectives
#
# By the end of this lesson, you will be able to:
# - **Apply AI-guided data processing strategies** for materials science datasets
# - **Select and optimize modern data tools** using AI consultation and performance analysis
# - **Create interactive dashboards** with AI-assisted development and deployment
# - **Evaluate AI tool effectiveness** through metacognitive reflection and peer collaboration
# - **Design ethical AI workflows** for materials science research and industry applications
#
# ---
#
# ## Modern Pedagogical Framework
#
# This lesson employs evidence-based learning strategies:
#
# ### 🧠 **Cognitive Load Management**
# - **Scaffolded Learning**: Progressive complexity with AI assistance
# - **Chunked Information**: Bite-sized concepts with immediate application
# - **Visual Learning**: Interactive diagrams and AI-generated explanations
#
# ### 🤝 **Social Learning**
# - **Peer Collaboration**: AI tool evaluation and optimization teams
# - **Expert Mentorship**: Industry guest speakers and AI-assisted guidance
# - **Community Building**: Shared AI prompt libraries and best practices
#
# ### 🔄 **Metacognitive Development**
# - **Reflection Journals**: Regular AI tool effectiveness assessment
# - **Learning Analytics**: AI-assisted progress tracking and adaptation
# - **Self-Regulation**: Independent AI tool selection and optimization
#
# ### 🌍 **Authentic Assessment**
# - **Real-World Projects**: Industry-relevant materials science problems
# - **Portfolio Development**: Showcase AI-augmented research capabilities
# - **Peer Review**: Collaborative evaluation of AI-assisted solutions
#
# ---

# %% [markdown]
# ## Week 1: AI-Guided Data Processing Strategy
#
# ### Learning Objectives
# - **Use AI to analyze data processing challenges** and recommend appropriate tools
# - **Apply AI-assisted data cleaning and validation** techniques for materials science datasets
# - **Design data processing workflows** using AI consultation and iteration
# - **Compare data processing approaches** with AI-guided performance analysis
# - **Reflect on AI limitations** in data processing recommendations and validation strategies
#
# ### Prerequisites
#
# **Complete Lesson 2** - You should have:
# - Working knowledge of prompt engineering principles
# - Experience with iterative AI interaction
# - Understanding of AI limitations and validation needs
# - Basic Python data manipulation skills from Lesson 1
#
# **AI Tools Ready**: Claude, ChatGPT, or GitHub Copilot configured and accessible

# %% [markdown]
# ## Mini-Lecture: AI-Assisted Data Processing Strategy (~20-25 min)
#
# ### The AI-Augmented Data Processing Workflow
#
# Traditional data processing follows a linear path: **Load → Clean → Analyze → Visualize**. AI augmentation transforms this into an **iterative, consultative process** where AI helps with decision-making at each step.
#
# **Core Principles for AI-Assisted Data Processing:**
#
# 1. **Problem-First Approach** — Start with the materials science question, not the tool
# 2. **AI Consultation** — Use AI to explore options and trade-offs before committing
# 3. **Iterative Refinement** — Test AI suggestions, gather feedback, improve approach
# 4. **Validation-Driven** — Always verify AI recommendations with data and domain knowledge
#
# ### AI Prompt Patterns for Data Processing
#
# **Pattern 1: Data Assessment**
# ```
# ROLE: Data science consultant
# AUDIENCE: Materials science researcher
# GOAL: Assess [dataset] for processing challenges and tool recommendations
# INPUTS: [Dataset description, file size, data types, research question]
# CONSTRAINTS: ≤200 words; include memory/time estimates; suggest 2-3 tool options
# TASK: Identify potential issues and recommend processing approach
# EVAL CRITERIA: Specific, actionable, considers materials science context
# ```
#
# **Pattern 2: Workflow Design**
# ```
# ROLE: Data processing specialist
# AUDIENCE: Materials engineering team
# GOAL: Design optimal workflow for [specific analysis task]
# INPUTS: [Data characteristics, performance requirements, constraints]
# CONSTRAINTS: ≤250 words; include step-by-step process; note potential bottlenecks
# TASK: Create processing pipeline with tool recommendations
# EVAL CRITERIA: Feasible, efficient, materials-science appropriate
# ```
#
# **Pattern 3: Performance Analysis**
# ```
# ROLE: Performance optimization expert
# AUDIENCE: Research computing team
# GOAL: Analyze and improve data processing performance
# INPUTS: [Current approach, performance metrics, bottlenecks]
# CONSTRAINTS: ≤180 words; suggest specific optimizations; include trade-offs
# TASK: Identify bottlenecks and recommend improvements
# EVAL CRITERIA: Specific, measurable, considers resource constraints
# ```
#
# ### Materials Science Data Processing Challenges
#
# **Common Issues in Materials Datasets:**
# - **Mixed data types**: Composition percentages, temperature ranges, property measurements
# - **Experimental uncertainty**: Measurement errors, instrument precision, sample variability
# - **Unit conversions**: SI vs. imperial, different temperature scales, pressure units
# - **Missing data**: Failed experiments, incomplete measurements, equipment issues
# - **Large file sizes**: High-resolution microscopy, extensive property databases
# - **Complex relationships**: Non-linear property correlations, phase transformations
#
# **AI Can Help With:**
# - **Tool selection** based on data characteristics and analysis goals
# - **Workflow optimization** for specific materials science tasks
# - **Error detection** and data validation strategies
# - **Performance tuning** for large materials datasets
# - **Visualization design** for materials property relationships
#
# **AI Limitations to Watch For:**
# - **Over-optimization**: May suggest complex solutions for simple problems
# - **Tool bias**: May favor certain libraries without considering alternatives
# - **Performance estimates**: May not account for your specific hardware/constraints
# - **Domain knowledge gaps**: May miss materials-specific considerations

# %% [markdown]
# ## Week 1 — Grading Rubric (15 pts)
#
# | Guided<br>Activity | Criterion | Excellent (full) | Partial | Pts |
# |:-:|---|---|---|---:|
# | 1 | AI-assisted data assessment | Clear problem framing, specific tool recommendations, materials context | Vague or generic suggestions | 5 |
# | 1 | Workflow design & iteration | 2+ iterations with KEEP/CHANGE notes, specific improvements | 1 iteration or superficial changes | 4 |
# | 2 | Performance analysis | Specific bottlenecks identified, measurable improvements suggested | Generic optimization advice | 3 |
# | 2 | Peer collaboration | Meaningful peer feedback, collaborative optimization | Minimal peer interaction | 3 |
#
# **Submission:** This notebook with prompts, outputs, reflections, and analysis in the Guided Activities below.
#
# > 💡 **Reminder:** Each reflection cell tells you the word count requirement and what will be graded. Aim to stay within the word limits, but don't worry if you exceed them slightly.

# %% [markdown]
# ### Guided Activity 1: AI-Assisted Data Processing Strategy (60-75 min)
#
# **Your Tasks**
# 1. **Choose a materials science dataset** (use provided sample or your own)
# 2. **Use AI to assess the dataset** and recommend processing approach
# 3. **Design a processing workflow** with AI consultation
# 4. **Iterate on the workflow** based on AI feedback
# 5. **Reflect on AI recommendations** and validation needs
#
# **Materials Science Dataset Options:**
# - **Stress-strain data**: Mechanical properties with experimental uncertainty
# - **Composition-property data**: Alloy compositions vs. mechanical/thermal properties
# - **Corrosion data**: Time-series measurements with environmental variables
# - **Microstructure data**: Image analysis results with particle size distributions
# - **Thermal analysis data**: DSC/TGA curves with temperature ramps
#
# **Tip:** Use the prompt patterns above and make sure to include specific materials science context in your prompts.

# %%
# === Dataset Selection ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Choose your dataset (uncomment one option or use your own)

# Option 1: Stress-strain data
# data = pd.read_csv('Al7075.csv')
# dataset_type = "Stress-strain data for Al7075 alloy"
# research_question = "Analyze mechanical properties and identify yield strength, ultimate strength, and elongation"

# Option 2: Composition-property data (sample)
np.random.seed(42)
data = pd.DataFrame({
    'Al_content': np.random.uniform(85, 99, 100),
    'Cu_content': np.random.uniform(0, 5, 100),
    'Mg_content': np.random.uniform(0, 3, 100),
    'Tensile_Strength_MPa': np.random.uniform(200, 600, 100),
    'Yield_Strength_MPa': np.random.uniform(150, 500, 100),
    'Elongation_Percent': np.random.uniform(2, 25, 100),
    'Hardness_HV': np.random.uniform(50, 200, 100)
})
dataset_type = "Aluminum alloy composition-property database"
research_question = "Identify composition-property relationships and optimize alloy design"

# Option 3: Corrosion data (sample)
# time_hours = np.linspace(0, 168, 50)  # 1 week
# corrosion_rate = 0.1 * np.exp(-time_hours/48) + 0.02 + 0.01 * np.random.randn(50)
# data = pd.DataFrame({
#     'Time_hours': time_hours,
#     'Corrosion_Rate_mm_per_year': corrosion_rate,
#     'Temperature_C': 25 + 5 * np.random.randn(50),
#     'pH': 7.5 + 0.5 * np.random.randn(50)
# })
# dataset_type = "Corrosion rate time-series data"
# research_question = "Analyze corrosion kinetics and environmental effects"

print(f"Dataset: {dataset_type}")
print(f"Research Question: {research_question}")
print(f"Dataset shape: {data.shape}")
print(f"\nFirst few rows:")
print(data.head())
print(f"\nData types:")
print(data.dtypes)
print(f"\nMemory usage: {data.memory_usage(deep=True).sum() / 1024:.1f} KB")

# %% [markdown]
# ### Step 1: AI Data Assessment
#
# Use the **Data Assessment** prompt pattern to analyze your dataset and get AI recommendations for processing approach.

# %%
# === AI Data Assessment Prompt ===
import textwrap

# Create your data assessment prompt using the pattern
prompt_data_assessment = f"""
ROLE: Data science consultant
AUDIENCE: Materials science researcher
GOAL: Assess {dataset_type} for processing challenges and tool recommendations
INPUTS: Dataset has {data.shape[0]} rows, {data.shape[1]} columns, {data.memory_usage(deep=True).sum() / 1024:.1f} KB memory usage. Research question: {research_question}. Data types include: {', '.join(data.dtypes.astype(str).unique())}
CONSTRAINTS: ≤200 words; include memory/time estimates; suggest 2-3 tool options
TASK: Identify potential issues and recommend processing approach
EVAL CRITERIA: Specific, actionable, considers materials science context
"""

print("Data Assessment Prompt:")
print(textwrap.indent(prompt_data_assessment, "    "))

# Copy this prompt to your AI tool and paste the response below
response_data_assessment = """
[Paste AI response here]
"""

print("\nAI Response:")
print(textwrap.indent(response_data_assessment, "    "))

# %% [markdown]
# ### Step 2: AI Workflow Design
#
# Use the **Workflow Design** prompt pattern to create a detailed processing pipeline based on the AI's recommendations.

# %%
# === AI Workflow Design Prompt ===
prompt_workflow_design = f"""
ROLE: Data processing specialist
AUDIENCE: Materials engineering team
GOAL: Design optimal workflow for {research_question}
INPUTS: {dataset_type} with {data.shape[0]} rows, {data.shape[1]} columns. Need to analyze composition-property relationships and optimize alloy design. Available tools: pandas, numpy, matplotlib, scikit-learn
CONSTRAINTS: ≤250 words; include step-by-step process; note potential bottlenecks
TASK: Create processing pipeline with tool recommendations
EVAL CRITERIA: Feasible, efficient, materials-science appropriate
"""

print("Workflow Design Prompt:")
print(textwrap.indent(prompt_workflow_design, "    "))

# Copy this prompt to your AI tool and paste the response below
response_workflow_design = """
[Paste AI response here]
"""

print("\nAI Response:")
print(textwrap.indent(response_workflow_design, "    "))

# %% [markdown]
# ## Week 2: Modern Data Tools and Interactive Dashboards
#
# ### Learning Objectives
# - **Use AI to assess data processing needs** and recommend appropriate tools for materials science datasets
# - **Apply AI-assisted performance benchmarking** with iterative optimization strategies
# - **Design data processing workflows** using AI consultation and validation
# - **Create interactive dashboards** with AI-assisted development and deployment
# - **Reflect on AI limitations** in tool recommendations and performance optimization advice
#
# ### Modern Data Tools for Materials Science
#
# **Polars** — Fast, memory-efficient alternative to pandas
# - **Best for**: Large datasets (>100MB), complex aggregations, memory-constrained systems
# - **Materials applications**: Property databases, composition analysis, statistical processing
# - **AI can help with**: Syntax conversion, optimization strategies, performance tuning
#
# **Dask** — Parallel computing for larger-than-memory datasets
# - **Best for**: Very large datasets (>1GB), distributed computing, complex workflows
# - **Materials applications**: High-resolution microscopy, extensive property databases
# - **AI can help with**: Workflow design, resource allocation, optimization strategies
#
# **Streamlit** — Interactive dashboard creation
# - **Best for**: Research communication, interactive data exploration, stakeholder presentations
# - **Materials applications**: Property visualization, composition optimization, results sharing
# - **AI can help with**: UI design, functionality planning, deployment strategies
#
# ### AI Prompt Patterns for Tool Selection
#
# **Pattern 1: Tool Assessment**
# ```
# ROLE: Data engineering consultant
# AUDIENCE: Materials science research team
# GOAL: Recommend optimal data processing tools for [specific materials dataset]
# INPUTS: [Dataset size, data types, analysis requirements, hardware constraints]
# CONSTRAINTS: ≤200 words; include performance estimates; suggest 2-3 tool options
# TASK: Analyze requirements and recommend processing approach
# EVAL CRITERIA: Specific, performance-focused, considers materials science context
# ```
#
# **Pattern 2: Performance Optimization**
# ```
# ROLE: Performance optimization specialist
# AUDIENCE: Research computing team
# GOAL: Optimize data processing performance for [specific analysis task]
# INPUTS: [Current approach, performance metrics, bottlenecks, requirements]
# CONSTRAINTS: ≤250 words; suggest specific optimizations; include trade-offs
# TASK: Identify bottlenecks and recommend improvements
# EVAL CRITERIA: Specific, measurable, considers resource constraints
# ```
#
# **Pattern 3: Dashboard Design**
# ```
# ROLE: UI/UX designer for scientific applications
# AUDIENCE: Materials science research team
# GOAL: Design interactive dashboard for [specific materials analysis]
# INPUTS: [Data characteristics, user needs, visualization requirements]
# CONSTRAINTS: ≤300 words; include user flow; suggest interactive elements
# TASK: Create dashboard design with AI-assisted implementation plan
# EVAL CRITERIA: User-friendly, scientifically accurate, interactive
# ```

# %% [markdown]
# ## Week 2 — Grading Rubric (20 pts)
#
# | Guided<br>Activity | Criterion | Excellent (full) | Partial | Pts |
# |:-:|---|---|---|---:|
# | 1 | AI tool assessment | Clear requirements analysis, specific tool recommendations, materials context | Vague or generic suggestions | 5 |
# | 1 | Performance optimization | 2+ iterations with KEEP/CHANGE notes, measurable improvements | 1 iteration or superficial changes | 4 |
# | 2 | Dashboard implementation | Functional Streamlit app, AI-guided development, user-friendly interface | Basic implementation without AI integration | 6 |
# | 2 | Peer collaboration | Meaningful peer feedback, collaborative optimization, shared learning | Minimal peer interaction | 3 |
# | 2 | Reflection & documentation | Specific AI limitations, actionable insights, clear documentation | Generic statements or poor documentation | 2 |
#
# **Submission:** This notebook with prompts, outputs, code, and reflections in the Guided Activities below.
#
# > 💡 **Reminder:** Each reflection cell tells you the word count requirement and what will be graded. Aim to stay within the word limits, but don't worry if you exceed them slightly.

# %% [markdown]
# ### Guided Activity 1: AI-Assisted Tool Selection and Performance Optimization (60–75 min)
#
# **Your Tasks**
# 1. **Choose a materials science dataset** (use provided sample or your own)
# 2. **Use AI to assess tool requirements** and recommend processing approach
# 3. **Implement AI-suggested optimizations** and measure performance improvements
# 4. **Iterate on the approach** based on AI feedback and performance results
# 5. **Reflect on AI recommendations** and validation strategies
#
# **Materials Science Dataset Options:**
# - **Large property database**: >10,000 alloy compositions with mechanical properties
# - **High-resolution microscopy data**: Image analysis results with particle distributions
# - **Time-series corrosion data**: Environmental exposure measurements over time
# - **Thermal analysis data**: DSC/TGA curves with multiple heating rates
# - **Composition optimization data**: Multi-element alloy design space exploration
#
# **Tip:** Use the prompt patterns above and make sure to include specific performance requirements and materials science context in your prompts.

# %%
# === Week 2 Dataset Selection and Setup ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import psutil
import textwrap

# Choose your dataset (uncomment one option or use your own)

# Option 1: Large property database (sample)
np.random.seed(42)
n_samples = 15000  # Large dataset for performance testing
data_large = pd.DataFrame({
    'Alloy_ID': [f'Alloy_{i:05d}' for i in range(1, n_samples + 1)],
    'Al_content': np.random.uniform(85, 99, n_samples),
    'Cu_content': np.random.uniform(0, 5, n_samples),
    'Mg_content': np.random.uniform(0, 3, n_samples),
    'Si_content': np.random.uniform(0, 2, n_samples),
    'Fe_content': np.random.uniform(0, 1, n_samples),
    'Tensile_Strength_MPa': np.random.uniform(200, 600, n_samples),
    'Yield_Strength_MPa': np.random.uniform(150, 500, n_samples),
    'Elongation_Percent': np.random.uniform(2, 25, n_samples),
    'Hardness_HV': np.random.uniform(50, 200, n_samples),
    'Density_g_cm3': np.random.uniform(2.6, 2.9, n_samples),
    'Processing_Temp_C': np.random.uniform(400, 600, n_samples),
    'Aging_Time_hours': np.random.uniform(1, 24, n_samples)
})
dataset_type_large = "Large aluminum alloy property database"
research_question_large = "Optimize alloy composition for high strength-to-weight ratio while maintaining corrosion resistance"

# Option 2: High-resolution microscopy data (sample)
# n_particles = 50000
# data_large = pd.DataFrame({
#     'Particle_ID': range(1, n_particles + 1),
#     'Area_pixels': np.random.lognormal(4, 1, n_particles),
#     'Perimeter_pixels': np.random.lognormal(3, 0.8, n_particles),
#     'Eccentricity': np.random.beta(2, 5, n_particles),
#     'X_position': np.random.uniform(0, 2048, n_particles),
#     'Y_position': np.random.uniform(0, 2048, n_particles),
#     'Phase': np.random.choice(['Alpha', 'Beta', 'Gamma'], n_particles)
# })
# dataset_type_large = "High-resolution microscopy particle analysis data"
# research_question_large = "Analyze particle size distribution and phase relationships"

print(f"Dataset: {dataset_type_large}")
print(f"Research Question: {research_question_large}")
print(f"Dataset shape: {data_large.shape}")
print(f"Memory usage: {data_large.memory_usage(deep=True).sum() / 1024 / 1024:.1f} MB")
print(f"\nFirst few rows:")
print(data_large.head())
